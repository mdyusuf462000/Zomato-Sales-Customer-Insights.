# %%
pip install pandas sqlalchemy pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

db_user = "root"
db_password = "yusuf"
db_host = "localhost"
db_name = "zomato_db"
table_name = "zomato"
engine = create_engine(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")

csv_file = r"C:\Users\yusuf\Downloads\archive\archive\zomato.csv"
df = pd.read_csv(csv_file)


df.to_sql(table_name, con=engine, if_exists="append", index=False)
print(f"\u2705 Data is the Successfully Upload")
# Out:
# ✅ Data is the Successfully Upload

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# 1 Step Data Claeing

# %%
#Columns name ko clean karna
df.columns = df.columns.str.strip().str.replace(" ", "_").str.replace("(for_two_people)", ("for two people"), regex=False)
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_costfor two people', 'listed_in(type)'],
#       dtype='object')

# %%
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_costfor two people listed_in(type)
# 0                        800          Buffet
# 1                        800          Buffet
# 2                        800          Buffet
# 3                        300          Buffet
# 4                        600          Buffet

# %%
#rate column ko float me change krna
df['rate'] = df['rate'].str.replace("/5","", regex=False).str.strip()
df['rate'] = pd.to_numeric(df['rate'],errors='coerce')
df['rate'].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_costfor two people listed_in(type)
# 0                        800          Buffet
# 1                        800          Buffet
# 2                        800          Buffet
# 3                        300          Buffet
# 4                        600          Buffet

# %%
df['approx_costfor two people'] = df['approx_costfor two people'].astype(str).str.replace(",", "").astype(float).astype(int)
df['approx_costfor two people']
# Out:
# 0      800
# 1      800
# 2      800
# 3      300
# 4      600
#       ...
# 143    100
# 144    150
# 145    450
# 146    800
# 147    200
# Name: approx_costfor two people, Length: 148, dtype: int32

# %%
df['approx_costfor two people'].dtype
# Out:
# dtype('int32')

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# name                         0
# online_order                 0
# book_table                   0
# rate                         0
# votes                        0
# approx_costfor two people    0
# listed_in(type)              0
# dtype: int64

# %%
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# 0

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_costfor two people listed_in(type)
# 0                        800          Buffet
# 1                        800          Buffet
# 2                        800          Buffet
# 3                        300          Buffet
# 4                        600          Buffet

# %%
df.describe()
# Out:
#              rate        votes  approx_costfor two people
# count  148.000000   148.000000                 148.000000
# mean     3.633108   264.810811                 418.243243
# std      0.402271   653.676951                 223.085098
# min      2.600000     0.000000                 100.000000
# 25%      3.300000     6.750000                 200.000000
# 50%      3.700000    43.500000                 400.000000
# 75%      3.900000   221.750000                 600.000000
# max      4.600000  4884.000000                 950.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       148 non-null    object
#  1   online_order               148 non-null    object
#  2   book_table                 148 non-null    object
#  3   rate                       148 non-null    float64
#  4   votes                      148 non-null    int64
#  5   approx_costfor two people  148 non-null    int32
#  6   listed_in(type)            148 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(4)
# memory usage: 7.6+ KB

# %%
df.sample(15)
# Out:
#                                   name online_order book_table  rate  votes  \
# 48                       Beijing Bites          Yes         No   3.7    679
# 74                     Rolls On Wheels           No         No   3.6    299
# 97                Ayda Persian Kitchen           No         No   3.7     39
# 85                     The Big O Bakes           No         No   4.0     66
# 136                 Sri Sai Tiffannies           No         No   3.3      0
# 92              Annapooraneshwari Mess           No         No   3.7      0
# 95          Vi Ra's Bar and Restaurant           No         No   3.3     62
# 132  Thanishka Nati And Karavali Style           No         No   3.1      0
# 133                  Swathi Cool Point           No         No   4.1      0
# 55                           FreshMenu          Yes         No   3.9    627
# 61                            Goa 0 Km          Yes        Yes   3.6    163
# ...

# %%
df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_costfor two people listed_in(type)
# 0                        800          Buffet
# 1                        800          Buffet
# 2                        800          Buffet
# 3                        300          Buffet
# 4                        600          Buffet

# %%
df.to_sql("zomato", con=engine, if_exists="replace", index=False)
# Out:
# 148

# %%
# Top 10 Highest Restaurants

query = "SELECT DISTINCT name, rate, votes FROM zomato ORDER BY rate DESC, votes DESC LIMIT 10;"
df_top_rated = pd.read_sql(query, con=engine)
df_top_rated
# Out:
#                      name  rate  votes
# 0                  Onesta   4.6   2556
# 1       Empire Restaurant   4.4   4884
# 2           Meghana Foods   4.4   4401
# 3  Corner House Ice Cream   4.3    345
# 4         Szechuan Dragon   4.2   1647
# 5               Smacznego   4.2    504
# 6                  Faasos   4.2    415
# 7                  Wamama   4.2    354
# 8           Peppy Peppers   4.2    244
# 9        The Coffee Shack   4.2    164

# %%
query = "SELECT online_order, COUNT(*) as count FROM zomato GROUP BY online_order;"
online_order_count = pd.read_sql(query, con=engine)
online_order_count
# Out:
#   online_order  count
# 0          Yes     58
# 1           No     90

# %%
#Low Price And best rateing Restaurants
query = "SELECT name, rate, `approx_costfor two people` FROM zomato WHERE `approx_costfor two people` < 500 AND rate > 4 ORDER BY rate DESC;"
df_affordable = pd.read_sql(query, con=engine)
df_affordable
# Out:
#                                           name  rate  \
# 0                       Corner House Ice Cream   4.3
# 1                                Frozen Bottle   4.2
# 2                             Shree Cool Point   4.1
# 3                                  Kabab Magic   4.1
# 4                             The Biryani Cafe   4.1
# 5                                Spicy Tandoor   4.1
# 6  Sri Guru Kottureshwara Davangere Benne Dosa   4.1
# 7                       Bengaluru Coffee House   4.1
# 8                            Swathi Cool Point   4.1
#
#    approx_costfor two people
# 0                        400
# 1                        400
# 2                        150
# 3                        400
# 4                        300
# 5                        150
# 6                        150
# 7                        300
# 8                        200

# %%
df.to_csv("C:/Users/yusuf/Documents/cleaned_data.csv", index=False

# %%
print(df.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_costfor two people listed_in(type)
# 0                        800          Buffet
# 1                        800          Buffet
# 2                        800          Buffet
# 3                        300          Buffet
# 4                        600          Buffet
